# %% [markdown]
# # INDONESIAN MOVIES ON NETFLIX

# %% [markdown]
# ## Table of Contents :
# 1. [INTRODUCTION](#1)
# 2. [NETFLIX DATA IN GENERAL](#2)
# 3. [WHAT IS THE NUMBER OF COMPARISONS FOR INDONESIAN TV SHOWS AND MOVIES ?](#3)
# 4. [HOW MANY INDONESIAN MOVIES WAS RELEASED EACH YEAR ON NETFLIX ?](#4)
# 5. [HOW MANY INDONESIAN MOVIES RATING & GENRE ARE THERE ON NETFLIX ?](#5)
# 6. [WHO ARE THE MOVIE DIRECTORS & ACTORS FROM INDONESIA ?](#6)
# 7. [CONCLUSION](#7)

# %% [markdown]
# ## **1. INTRODUCTION** <a name="1"></a>

# %% [markdown]
# **Netflix** is a streaming service that allows our members to watch a wide variety of award-winning TV shows, movies, documentaries, and more on thousands of internet-connected devices In over 190 countries.
#
# Indonesian movies on netflix are increasingly taking an international watch. More and more of these high-quality Indonesian movies have sprung up. This shows how Indonesian movies industry has grown. Not just playing in theaters, an Indonesian movies can be enjoyed through the netflix streaming service. You can go to movies that have been shown long and new at any time or place. long and new at any time or place.
#
# But on this occasion I'm not going to discuss how good Indonesian movies  are. I'm trying to show you facts or insights about Indonesian movies on Netflix.

# %% [markdown]
# ## Context
#
# - What : Netflix is a streaming service that allows our members to watch a wide variety of award-winning TV shows, movies, documentaries, and more on thousands of internet-connected devices In over 190 countries.
# - Who : One of the objects that I will review are Indonesian movie directors and actors
# - Where :Indoeian Movies on Netflix.com from datasets : netflix_titles.csv at https://www.kaggle.com/code/manjunathgb/practical-4/data
# - When : 2008 - 2021, excluding data in 2022.
# - Why : I'm trying to show you facts or insights about Indonesian movies on Netflix.
# - How : I use numpy, pandas, matplotlib, and seaborn libraries. I put my code in note book called 'Blog Post.ipnyb' and the result can give us some insight about Indonesian Movies on Netflix. And also, I will focus on the Indonesian movies data alone, because For a TV show in Indonesia, there are only two data.

# %% [markdown]
# ### *Importing all the necessary libraries*

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from textblob import TextBlob

# %% [markdown]
# ### *Importing the dataset*

# %%
df = pd.read_csv('./netflix_titles.csv')
df.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# Our data set has 12 features and 8807 examples

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ### *Data Cleaning*

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# The missing values are in:
#
# - director: Very less information-not needed for the analysis so I will be leting this
# - cast: this var has too many diferent values too so I will be leting this
# - country: this is a importante variable so wi will think how to fix it (maybe mode)
# - date_added: there are just a few cases, so lets scrap them
# - rating: there are just a few cases, so lets scrap them
# - duration : there are just a few cases, so lets scrap them

# %% [markdown]
# ### *Let's fix the missing "rating"*

# %%
df["rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df[df["rating"].isna()]
# Out:
#      show_id     type                                              title  \
# 5989   s5990    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 6827   s6828  TV Show                  Gargantia on the Verdurous Planet
# 7312   s7313  TV Show                                       Little Lunch
# 7537   s7538    Movie                               My Honor Was Loyalty
#
#              director                                               cast  \
# 5989              NaN                        Oprah Winfrey, Ava DuVernay
# 6827              NaN  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...
# 7312              NaN  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# 7537  Alessandro Pepe  Leone Frisa, Paolo Vaccarino, Francesco Miglio...
#
#         country        date_added  release_year rating  duration  \
# 5989        NaN  January 26, 2017          2017    NaN    37 min
# 6827      Japan  December 1, 2016          2013    NaN  1 Season
# 7312  Australia  February 1, 2018          2015    NaN  1 Season
# 7537      Italy     March 1, 2017          2015    NaN   115 min
#
#                                  listed_in  \
# 5989                                Movies
# 6827  Anime Series, International TV Shows
# 7312                 Kids' TV, TV Comedies
# 7537                                Dramas
#
#                                             description
# 5989  Oprah Winfrey sits down with director Ava DuVe...
# 6827  After falling through a wormhole, a space-dwel...
# 7312  Adopting a child's perspective, this show take...
# 7537  Amid the chaos and horror of World War II, a c...

# %% [markdown]
# Since there are only 4 rows so I decided to find there replacements from internet.

# %%
rating_replacements = {
    5989: 'TV-PG',
    6827: 'TV-14',
    7312: 'TV-MA',
    7537: 'TV-MA',
}

for id, rate in rating_replacements.items():
    df.iloc[id, 8] = rate
    
df['rating'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### *Fix "date_added" column*

# %%
df[df['date_added'].isna()]
# Out:
#      show_id     type                                        title director  \
# 6066   s6067  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 6174   s6175  TV Show              Anthony Bourdain: Parts Unknown      NaN
# 6795   s6796  TV Show                                      Frasier      NaN
# 6806   s6807  TV Show                                      Friends      NaN
# 6901   s6902  TV Show                              Gunslinger Girl      NaN
# 7196   s7197  TV Show                                     Kikoriki      NaN
# 7254   s7255  TV Show                          La Familia P. Luche      NaN
# 7406   s7407  TV Show                                        Maron      NaN
# 7847   s7848  TV Show                                 Red vs. Blue      NaN
# 8182   s8183  TV Show                 The Adventures of Figaro Pho      NaN
#
#                                                    cast         country  \
# 6066  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...  United Kingdom
# 6174                                   Anthony Bourdain   United States
# 6795  Kelsey Grammer, Jane Leeves, David Hyde Pierce...   United States
# 6806  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...   United States
# 6901  Yuuka Nanri, Kanako Mitsuhashi, Eri Sendai, Am...           Japan
# 7196                                      Igor Dmitriev             NaN
# 7254  Eugenio Derbez, Consuelo Duval, Luis Manuel Áv...   United States
# 7406  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...   United States
# 7847  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...   United States
# 8182  Luke Jurevicius, Craig Behenna, Charlotte Haml...       Australia
#
#      date_added  release_year rating    duration  \
# 6066        NaN          2013  TV-MA   2 Seasons
# 6174        NaN          2018  TV-PG   5 Seasons
# 6795        NaN          2003  TV-PG  11 Seasons
# 6806        NaN          2003  TV-14  10 Seasons
# 6901        NaN          2008  TV-14   2 Seasons
# 7196        NaN          2010   TV-Y   2 Seasons
# 7254        NaN          2012  TV-14   3 Seasons
# 7406        NaN          2016  TV-MA   4 Seasons
# 7847        NaN          2015     NR  13 Seasons
# 8182        NaN          2015  TV-Y7   2 Seasons
#
#                                               listed_in  \
# 6066           British TV Shows, TV Comedies, TV Dramas
# 6174                                         Docuseries
# 6795                     Classic & Cult TV, TV Comedies
# 6806                     Classic & Cult TV, TV Comedies
# 6901                       Anime Series, Crime TV Shows
# 7196                                           Kids' TV
# 7254  International TV Shows, Spanish-Language TV Sh...
# 7406                                        TV Comedies
# 7847  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 8182                              Kids' TV, TV Comedies
#
#                                             description
# 6066  Set during the Russian Revolution, this comic ...
# 6174  This CNN original series has chef Anthony Bour...
# 6795  Frasier Crane is a snooty but lovable Seattle ...
# 6806  This hit sitcom follows the merry misadventure...
# 6901  On the surface, the Social Welfare Agency appe...
# 7196  A wacky rabbit and his gang of animal pals hav...
# 7254  This irreverent sitcom featues Ludovico, Feder...
# 7406  Marc Maron stars as Marc Maron, who interviews...
# 7847  This parody of first-person shooter games, mil...
# 8182  Imagine your worst fears, then multiply them: ...

# %% [markdown]
# Since it is difficult to find the date_added so I will drop these as they are only 10 rows.

# %%
df=df[df["date_added"].notna()]

# %%
df[df['date_added'].isna()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# ### *Fix "country" missing values*

# %%
df['country'] = df['country'].fillna(df['country'].mode()[0])

# %% [markdown]
# There are some entry where "country" has multiple values. so i think i will add a new column with just the first one so we can check witch regions have more productions

# %%
# Lets retrieve just the first country
df['principal_country'] = df['country'].apply(lambda x: x.split(",")[0])
df['principal_country'].head()
# Out:
# 0    United States
# 1     South Africa
# 2    United States
# 3    United States
# 4            India
# Name: principal_country, dtype: object

# %% [markdown]
# ### *Fix "duration" missing values*

# %%
df[df["duration"].isna()]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  74 min
# 5794  Louis C.K.  United States  September 16, 2016          2010  84 min
# 5813  Louis C.K.  United States     August 15, 2016          2015  66 min
#
#      duration listed_in                                        description  \
# 5541      NaN    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794      NaN    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813      NaN    Movies  The comic puts his trademark hilarious/thought...
#
#      principal_country
# 5541     United States
# 5794     United States
# 5813     United States

# %%
duration_replacements = {
    5541: '74 Min',
    5794: '82 Min',
    5813: '66 Min',
}

for id, time in duration_replacements.items():
    df.iloc[id, 9] = time
    
df['rating'].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# show_id                 0
# type                    0
# title                   0
# director             2624
# cast                  825
# country                 0
# date_added              0
# release_year            0
# rating                  0
# duration                0
# listed_in               0
# description             0
# principal_country       0
# dtype: int64

# %% [markdown]
# Look up, I let field data to director and cast.

# %% [markdown]
# ### *Makesure no data duplicated*

# %%
df[df['title'].duplicated(keep="last")]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, principal_country]
# Index: []

# %%
df[df['title'].duplicated(keep="first")]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, principal_country]
# Index: []

# %%
print(df.duplicated().sum()) #checking if there is any duplicate items
# Out:
# 0

# %% [markdown]
# Look up, the result is not data duplicated..

# %% [markdown]
# ## **2. NETFLIX DATA IN GENERAL** <a name="2"></a>

# %%
type = df['type'].value_counts()

# %%
plt.figure(figsize = (8,8))
#plot for first chart
sns.barplot(x = type.index.values, y = type)
#adding text on the bar
for i in range (type.shape[0]): 
    count = type[i]
    plt.text(i, count-1.5, count, ha = 'center', va='top', color = 'black', fontsize = 18)

#customizing chart
plt.title('Type of Netflix Content on Number', fontsize = 15)
plt.xlabel(' ')
plt.ylabel('Frequency', fontsize = 15)
plt.xticks(rotation=-0, ha ='left', fontsize = 12);

# %%
labels = ['TV Shows', 'Movies']
colors = sns.color_palette('Set1')
plt.figure(figsize=(8,8))
plt.pie(df['type'].value_counts().sort_values(), labels = labels, colors = ['lightblue','royalblue'], autopct='%1.2f%%', explode=[0.1,0.1], startangle=90)
plt.title("Type of Netflix Content on Percent", size=16)
plt.axis('equal')
plt.show()
print("\n Netflix have more Movies than TV Shows")
# Out:
#  Netflix have more Movies than TV Shows

# %%
df['country'].value_counts()[:15]
# Out:
# United States     3642
# India              972
# United Kingdom     418
# Japan              244
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Turkey             105
# Nigeria             95
# Australia           86
# Taiwan              81
# Indonesia           79
# Name: country, dtype: int64

# %% [markdown]
# Top 15 Country which has most number of title and Indonesia is in the last position with 79 Titles.

# %%
top15 = df['country'].value_counts()[:15]
plt.figure(figsize = (15,8))
#plot for first chart
sns.barplot(x = top15.index.values, y = top15)
#adding text on the bar
for i in range (top15.shape[0]): 
    count = top15[i]
    plt.text(i, count-1.5, count, ha = 'center', va='bottom', color = 'black', fontsize = 14)

#customizing chart
plt.title('Top 15 Country which has most number of title', fontsize = 15)
plt.xlabel('Countries ', fontsize =15)
plt.ylabel('Frequency', fontsize = 15)
plt.xticks(rotation=-30, ha ='left', fontsize = 12);

# %% [markdown]
# ### *Indonesian Data Exploration*

# %%
df_indonesia=df[df['country']=='Indonesia']
df_indonesia.head(10)
# Out:
#      show_id   type                                  title  \
# 452     s453  Movie                          A Perfect Fit
# 534     s535  Movie                    Si Doel the Movie 2
# 1090   s1091  Movie  Story of Kale: When Someone's in Love
# 1136   s1137  Movie                   Tersanjung the Movie
# 1221   s1222  Movie              Generasi 90an: Melankolia
# 1237   s1238  Movie                               Mariposa
# 1269   s1270  Movie                             Geez & Ann
# 1323   s1324  Movie                           Layla Majnun
# 1372   s1373  Movie                            June & Kopi
# 1413   s1414  Movie                            Tanda Tanya
#
#                                director  \
# 452                   Hadrah Daeng Ratu
# 534                          Rano Karno
# 1090              Angga Dwimas Sasongko
# 1136  Hanung Bramantyo, Pandu Adjisurya
# 1221               Mohammad Irfan Ramly
# 1237                      Fajar Bustomi
# 1269                        Rizki Balki
# 1323                         Monty Tiwa
# 1372                  Noviandra Santosa
# 1413                   Hanung Bramantyo
#
#                                                    cast    country  \
# 452   Nadya Arina, Refal Hady, Giorgino Abraham, Ang...  Indonesia
# 534   Maudy Koesnaedi, Rano Karno, Cornelia Agatha, ...  Indonesia
# 1090  Ardhito Pramono, Aurélie Moeremans, Arya Salok...  Indonesia
# 1136  Clara Bernadeth, Giorgino Abraham, Kevin Ardil...  Indonesia
# 1221  Ari Irham, Aghniny Haque, Taskya Namya, Marcel...  Indonesia
# 1237  Adhisty Zara, Angga Yunanda, Dannia Salsabila,...  Indonesia
# 1269  Hanggini, Junior Roberts, Roy Sungkono, Shenin...  Indonesia
# 1323  Reza Rahadian, Acha Septriasa, Baim Wong, Beby...  Indonesia
# 1372  Acha Septriasa, Ryan Delon, Makayla Rose Hilli...  Indonesia
# 1413  Reza Rahadian, Revalina S. Temat, Rio Dewanto,...  Indonesia
#
#              date_added  release_year rating duration  \
# 452       July 15, 2021          2021  TV-PG  113 min
# 534        July 6, 2021          2019   TV-G   95 min
# 1090      April 8, 2021          2020  TV-PG   78 min
# 1136      April 1, 2021          2021  TV-14  114 min
# 1221     March 11, 2021          2020  TV-14   94 min
# 1237      March 4, 2021          2020  TV-14  116 min
# 1269  February 25, 2021          2021  TV-PG  106 min
# 1323  February 11, 2021          2020  TV-14  119 min
# 1372   January 28, 2021          2021  TV-PG   90 min
# 1413   January 14, 2021          2011  TV-MA  102 min
#
#                                               listed_in  \
# 452              Comedies, Dramas, International Movies
# 534                        Dramas, International Movies
# 1090      Dramas, International Movies, Romantic Movies
# 1136      Dramas, International Movies, Romantic Movies
# 1221                       Dramas, International Movies
# 1237    Comedies, International Movies, Romantic Movies
# 1269      Dramas, International Movies, Romantic Movies
# 1323      Dramas, International Movies, Romantic Movies
# 1372  Children & Family Movies, Dramas, Internationa...
# 1413                       Dramas, International Movies
#
#                                             description principal_country
# 452   Sparks fly when a fashion blogger in Bali meet...         Indonesia
# 534   As Sarah and her child look to settle in Jakar...         Indonesia
# 1090  After leaving a toxic relationship, Dinda emba...         Indonesia
# 1136  After growing up in a tumultuous household, Yu...         Indonesia
# 1221  After the devastating loss of a loved one, Abb...         Indonesia
# 1237  New student Acha falls for Iqbal, a high-achie...         Indonesia
# 1269  After falling for Geez, a heartthrob at school...         Indonesia
# 1323  While in Azerbaijan, Layla, an Indonesian scho...         Indonesia
# 1372  A street dog is taken in by a young couple, an...         Indonesia
# 1413  In a story of interconnected lives, three fami...         Indonesia

# %% [markdown]
# **Column explanations in Netflix dataset:**
# * show_id: unique ID for each movie
# * type: 'Movie' or 'TV Show'
# * title: official movie title
# * director: name of director
# * cast: list of actors' names in movie
# * country: country where the movie was produced
# * date_added: date that the movie was added to Netflix
# * release_year: year that the movie was originally released
# * rating: age rating of movie
# * duration: duration of the movie in minutes
# * listed_in: relevant genres of the movie
# * description: short description of the movie plot
#
# The only columns that I will be using here are title, release_year, listed_in and country as title and release_year are important identifiers, listed_in allows us to find the best movies from different genres and country allows us to find the best movies for each country.

# %%
df_indonesia.shape
# Out:
# (79, 13)

# %%
df_indonesia.nunique()
# Out:
# show_id              79
# type                  2
# title                79
# director             49
# cast                 78
# country               1
# date_added           53
# release_year         16
# rating                5
# duration             47
# listed_in            20
# description          79
# principal_country     1
# dtype: int64

# %%
df_indonesia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79 entries, 452 to 8725
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   show_id            79 non-null     object
#  1   type               79 non-null     object
#  2   title              79 non-null     object
#  3   director           77 non-null     object
#  4   cast               78 non-null     object
#  5   country            79 non-null     object
#  6   date_added         79 non-null     object
#  7   release_year       79 non-null     int64
#  8   rating             79 non-null     object
#  9   duration           79 non-null     object
#  10  listed_in          79 non-null     object
#  11  description        79 non-null     object
#  12  principal_country  79 non-null     object
# dtypes: int64(1), object(12)
# memory usage: 8.6+ KB

# %%
df_indonesia.isnull().sum()
# Out:
# show_id              0
# type                 0
# title                0
# director             2
# cast                 1
# country              0
# date_added           0
# release_year         0
# rating               0
# duration             0
# listed_in            0
# description          0
# principal_country    0
# dtype: int64

# %% [markdown]
# There're missing values for Indonesian data in director and cast, but this is relatively small and we can complete it

# %% [markdown]
# ## **3. WHAT IS THE NUMBER OF COMPARISONS FOR INDONESIAN TV SHOWS AND MOVIES  ?** <a name="3"></a>

# %%
df_indonesia['type'].value_counts()[:15]
# Out:
# Movie      77
# TV Show     2
# Name: type, dtype: int64

# %%
df_TVshow=df_indonesia[(df_indonesia['type']=='TV Show')][['show_id', 'type', 'title', 'director', 'cast','date_added',
       'release_year', 'rating', 'duration', 'listed_in', 'description']] #  filter Movies data from dataset

# %%
df_TVshow.head()
# Out:
#      show_id     type                                        title director  \
# 1605   s1606  TV Show  Check The Store Next Door: The Next Chapter      NaN
# 6937   s6938  TV Show                               Hati Perempuan      NaN
#
#                                                    cast        date_added  \
# 1605  Ernest Prakasa, Chew Kin Wah, Dion Wiyoko, Mor...  December 2, 2020
# 6937  Saharul Ridzwan, Mia Ahmad, Hafreez Adam, Hafe...   August 21, 2017
#
#       release_year rating   duration  \
# 1605          2020  TV-14  2 Seasons
# 6937          2015  TV-14   1 Season
#
#                                               listed_in  \
# 1605     International TV Shows, TV Comedies, TV Dramas
# 6937  International TV Shows, Romantic TV Shows, TV ...
#
#                                             description
# 1605  When a former shop owner grows bored of retire...
# 6937  Sparks of both passion and contempt fly when a...

# %%
df_movie=df_indonesia[(df_indonesia['type']=='Movie')][['show_id', 'type', 'title', 'director', 'cast','date_added',
       'release_year', 'rating', 'duration', 'listed_in', 'description']] #  filter Movies data from dataset

# %%
df_movie.head ()
# Out:
#      show_id   type                                  title  \
# 452     s453  Movie                          A Perfect Fit
# 534     s535  Movie                    Si Doel the Movie 2
# 1090   s1091  Movie  Story of Kale: When Someone's in Love
# 1136   s1137  Movie                   Tersanjung the Movie
# 1221   s1222  Movie              Generasi 90an: Melankolia
#
#                                director  \
# 452                   Hadrah Daeng Ratu
# 534                          Rano Karno
# 1090              Angga Dwimas Sasongko
# 1136  Hanung Bramantyo, Pandu Adjisurya
# 1221               Mohammad Irfan Ramly
#
#                                                    cast      date_added  \
# 452   Nadya Arina, Refal Hady, Giorgino Abraham, Ang...   July 15, 2021
# 534   Maudy Koesnaedi, Rano Karno, Cornelia Agatha, ...    July 6, 2021
# 1090  Ardhito Pramono, Aurélie Moeremans, Arya Salok...   April 8, 2021
# 1136  Clara Bernadeth, Giorgino Abraham, Kevin Ardil...   April 1, 2021
# 1221  Ari Irham, Aghniny Haque, Taskya Namya, Marcel...  March 11, 2021
#
#       release_year rating duration  \
# 452           2021  TV-PG  113 min
# 534           2019   TV-G   95 min
# 1090          2020  TV-PG   78 min
# 1136          2021  TV-14  114 min
# 1221          2020  TV-14   94 min
#
#                                           listed_in  \
# 452          Comedies, Dramas, International Movies
# 534                    Dramas, International Movies
# 1090  Dramas, International Movies, Romantic Movies
# 1136  Dramas, International Movies, Romantic Movies
# 1221                   Dramas, International Movies
#
#                                             description
# 452   Sparks fly when a fashion blogger in Bali meet...
# 534   As Sarah and her child look to settle in Jakar...
# 1090  After leaving a toxic relationship, Dinda emba...
# 1136  After growing up in a tumultuous household, Yu...
# 1221  After the devastating loss of a loved one, Abb...

# %%
temp_df = df_indonesia
plt.figure(figsize = (12,8))
plt.style.use('seaborn-whitegrid')
ax = sns.countplot(x = 'type', data = temp_df, palette = "colorblind")
plt.title('Indonesian Movies Release Each Years' ,size=16)
plt.xlabel('Type', size=14)
plt.ylabel('Number of Titles', size=14)
plt.xticks(rotation = 0)
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.35, p.get_height()+0.25), va = 'bottom', color = 'black',fontsize =14)

# %%
labels = ['TV Shows', 'Movies']
colors = sns.color_palette('Set2')
plt.figure(figsize=(8,10))
plt.pie(df_indonesia['type'].value_counts().sort_values(), labels = labels, colors = ['lightblue','royalblue'], autopct='%25.2f%%', explode=[0.1,0.1], startangle=90)
plt.title("Type of Netflix Content")
plt.axis('equal')
plt.show()
print("\n Indonesian dataset consists of 77 (97.47%)for Movies and 2 (2.53%) for TV Shows")
# Out:
#  Indonesian dataset consists of 77 (97.47%)for Movies and 2 (2.53%) for TV Shows

# %% [markdown]
# According to the above information, there are only two Indonesian TV shows playing on the netflix channel. The "check the store next door" was released in 2020 and "Hati Perempuan" was released in 2017, as for the Indonesian Movies there are many titles.
#
# So, I'll just take care of the Indonesian movies on netflix.

# %% [markdown]
# ## **4. HOW MANY INDONESIAN MOVIES WAS RELEASED EACH YEAR ON NETFLIX ?** <a name="4"></a>

# %%
temp_df = df_indonesia[df_indonesia['type']=='Movie']

plt.figure(figsize = (12,8))
plt.style.use('seaborn-whitegrid')
ax = sns.countplot(x = 'release_year', data = temp_df, palette = "colorblind")
plt.title('Indonesian Movies Release Each Years' ,size=16)
plt.xlabel('Year of Release', size=14)
plt.ylabel('Number of Movies', size=14)
plt.xticks(rotation = 45)
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.25, p.get_height()+0.25), va = 'bottom', color = 'black')

# %% [markdown]
# The above graph shows most Indonesian movies released in 2018 and 2020

# %% [markdown]
# ## **5. HOW MANY INDONESIAN MOVIES RATING & GENRE ARE THERE ON NETFLIX ?**<a name="5"></a>

# %% [markdown]
# ### *Indonesian Movies Rating*

# %%
temp_df = df_indonesia[df_indonesia['type']=='Movie'] ##filter movie
temp_df['rating'].value_counts()[:15]
# Out:
# TV-14    33
# TV-PG    20
# TV-MA    14
# TV-G      8
# R         2
# Name: rating, dtype: int64

# %%
plt.figure(figsize=(10,10))
ax = sns.countplot(x="rating", data=temp_df, palette = "pastel", order=df_indonesia['rating'].value_counts().index[0:15])
plt.xlabel('RATING', fontsize = 14)
plt.ylabel('NUMBER of TITLES', fontsize = 14)
plt.title('Rating of Indonesian Movies in Netflix', size = 16)
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.35, p.get_height()+1), fontsize = 14, va = 'top', color = 'black')

# %% [markdown]
# ### Rate reference
# Let’s look at the definitions of the different ratings according to [http://www.tvguidelines.org/](“http://www.tvguidelines.org/resources/TV_Parental_guidelines_Brochure.pdf”)
#
#
# <center> Table: Meaning of the different ratings </center>
#
# |     Rating      |     Meaning                                                                                                                                        |
# |-----------------|----------------------------------------------------------------------------------------------------------------------------------------------------|
# |     NC-17       |     No One 17 and Under Admitted. Clearly adult. Young children will not be admitted to   watch the film.                                          |
# |     TV-Y7-FV    |     Is used to indicate that a program contains “fantasy   violence” that may be more intense or combative than other TV-Y7 programs.    |
# |     UR          |     Unrated                                                                                                                                        |
# |     G           |     Most parents would find this program suitable for all ages.                                                                                  |
# |     NR          |     Not Rated                                                                                                                                      |
# |     TV-Y7       |     This program is designed for children age 7 and above.                                                                                         |
# |     TV-G        |     This program is designed for children age 7 and above.                                                                                         |
# |     TV-Y        |     This program is designed to be appropriate for all   children                                                                                  |
# |     PG          |     This program contains material that parents may find   unsuitable for younger children.                                                        |
# |     PG-13       |     Some material may be inappropriate for   children under 13                                                                                     |
# |     TV-PG       |     This program contains material that parents may find   unsuitable for younger children.                                                        |
# |     R           |     Children Under 17 Require Accompanying Parent or Adult Guardian                                                                                |
# |     TV-14       |     This   program contains some material that many parents would find unsuitable for   children under 14 years of     age.                        |
# |     TV-MA       |     This   program is specifically designed to be viewed by adults and therefore may be unsuitable   for children     under 17                     |
#
#
# <n> </n>
# The above graph shows the number of Indonesian movies in the data frame for each rating. There are three top rankings, namely TV-14, TV-PG, and TV-MA.

# %% [markdown]
# ### *Indonesian Movies Genre*

# %%
listed_in_count = temp_df.copy()
listed_in_count = pd.concat([listed_in_count, temp_df["listed_in"].str.split(",", expand = True)], axis = 1)
listed_in_count
# Out:
#      show_id   type                                  title  \
# 452     s453  Movie                          A Perfect Fit
# 534     s535  Movie                    Si Doel the Movie 2
# 1090   s1091  Movie  Story of Kale: When Someone's in Love
# 1136   s1137  Movie                   Tersanjung the Movie
# 1221   s1222  Movie              Generasi 90an: Melankolia
# ...      ...    ...                                    ...
# 8317   s8318  Movie                          The Gathering
# 8374   s8375  Movie                      The Jungle School
# 8472   s8473  Movie                     The Rainbow Troops
# 8509   s8510  Movie           The Sinking Of Van Der Wijck
# 8725   s8726  Movie                   What's Up With Love?
#
#                                director  \
# 452                   Hadrah Daeng Ratu
# 534                          Rano Karno
# 1090              Angga Dwimas Sasongko
# 1136  Hanung Bramantyo, Pandu Adjisurya
# 1221               Mohammad Irfan Ramly
# ...                                 ...
# 8317                         Nia Dinata
# 8374                          Riri Riza
# 8472                          Riri Riza
# 8509                       Sunil Soraya
# 8725          Rudy Soedjarwo, Riri Riza
#
#                                                    cast    country  \
# 452   Nadya Arina, Refal Hady, Giorgino Abraham, Ang...  Indonesia
# 534   Maudy Koesnaedi, Rano Karno, Cornelia Agatha, ...  Indonesia
# 1090  Ardhito Pramono, Aurélie Moeremans, Arya Salok...  Indonesia
# 1136  Clara Bernadeth, Giorgino Abraham, Kevin Ardil...  Indonesia
# 1221  Ari Irham, Aghniny Haque, Taskya Namya, Marcel...  Indonesia
# ...                                                 ...        ...
# 8317  Cut Mini Theo, Tora Sudiro, Aida Nurmala, Sury...  Indonesia
# 8374  Prisia Nasution, Nyungsang Bungo, Rukman Rosad...  Indonesia
# 8472  Cut Mini Theo, Ikranagara, Lukman Sardi, Ario ...  Indonesia
# 8509  Herjunot Ali, Pevita Pearce, Reza Rahadian, Ra...  Indonesia
# 8725  Dian Sastrowardoyo, Nicholas Saputra, Ladya Ch...  Indonesia
#
#               date_added  release_year rating duration  \
# 452        July 15, 2021          2021  TV-PG  113 min
# 534         July 6, 2021          2019   TV-G   95 min
# 1090       April 8, 2021          2020  TV-PG   78 min
# 1136       April 1, 2021          2021  TV-14  114 min
# 1221      March 11, 2021          2020  TV-14   94 min
# ...                  ...           ...    ...      ...
# 8317    December 8, 2018          2003  TV-14  124 min
# 8374    October 30, 2018          2013  TV-PG   90 min
# 8472    October 21, 2018          2008  TV-PG  119 min
# 8509  September 28, 2018          2013  TV-14  163 min
# 8725    December 8, 2018          2002      R  110 min
#
#                                               listed_in  \
# 452              Comedies, Dramas, International Movies
# 534                        Dramas, International Movies
# 1090      Dramas, International Movies, Romantic Movies
# 1136      Dramas, International Movies, Romantic Movies
# 1221                       Dramas, International Movies
# ...                                                 ...
# 8317             Comedies, Dramas, International Movies
# 8374                       Dramas, International Movies
# 8472  Children & Family Movies, Dramas, Internationa...
# 8509      Dramas, International Movies, Romantic Movies
# 8725      Dramas, International Movies, Romantic Movies
#
#                                             description principal_country  \
# 452   Sparks fly when a fashion blogger in Bali meet...         Indonesia
# 534   As Sarah and her child look to settle in Jakar...         Indonesia
# 1090  After leaving a toxic relationship, Dinda emba...         Indonesia
# 1136  After growing up in a tumultuous household, Yu...         Indonesia
# 1221  After the devastating loss of a loved one, Abb...         Indonesia
# ...                                                 ...               ...
# 8317  Between divorce, bad relationships and coming ...         Indonesia
# 8374  An idealistic young woman travels to the jungl...         Indonesia
# 8472  Two Indonesian teachers embrace an inspiring c...         Indonesia
# 8509  When a young man leaves home to fulfill the wi...         Indonesia
# 8725  A popular high school girl strains her relatio...         Indonesia
#
#                              0                      1                      2
# 452                   Comedies                 Dramas   International Movies
# 534                     Dramas   International Movies                   None
# 1090                    Dramas   International Movies        Romantic Movies
# 1136                    Dramas   International Movies        Romantic Movies
# 1221                    Dramas   International Movies                   None
# ...                        ...                    ...                    ...
# 8317                  Comedies                 Dramas   International Movies
# 8374                    Dramas   International Movies                   None
# 8472  Children & Family Movies                 Dramas   International Movies
# 8509                    Dramas   International Movies        Romantic Movies
# 8725                    Dramas   International Movies        Romantic Movies
#
# [77 rows x 16 columns]

# %%
listed_in_count = listed_in_count.melt(id_vars = ["type", "title"], value_vars = range(3), value_name = "listed_in")
listed_in_count = listed_in_count[listed_in_count["listed_in"].notna()]
listed_in_count
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_131808\1973880937.py:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   listed_in_count = listed_in_count.melt(id_vars = ["type", "title"], value_vars = range(3), value_name = "listed_in")
#       type                                  title variable  \
# 0    Movie                          A Perfect Fit        0
# 1    Movie                    Si Doel the Movie 2        0
# 2    Movie  Story of Kale: When Someone's in Love        0
# 3    Movie                   Tersanjung the Movie        0
# 4    Movie              Generasi 90an: Melankolia        0
# ..     ...                                    ...      ...
# 224  Movie                             The Dancer        2
# 226  Movie                          The Gathering        2
# 228  Movie                     The Rainbow Troops        2
# 229  Movie           The Sinking Of Van Der Wijck        2
# 230  Movie                   What's Up With Love?        2
#
#                  listed_in
# 0                 Comedies
# 1                   Dramas
# 2                   Dramas
# 3                   Dramas
# 4                   Dramas
# ..                     ...
# 224        Romantic Movies
# 226   International Movies
# 228   International Movies
# 229        Romantic Movies
# 230        Romantic Movies
#
# [202 rows x 4 columns]

# %%
listed_in_count["listed_in"].unique()
# Out:
# array(['Comedies', 'Dramas', 'Children & Family Movies',
#        'Action & Adventure', 'Documentaries', 'Horror Movies', ' Dramas',
#        ' International Movies', ' Independent Movies',
#        ' Faith & Spirituality', ' Horror Movies', ' Romantic Movies',
#        ' Music & Musicals', ' Sports Movies'], dtype=object)

# %%
temp_df["listed_in"].value_counts()
# Out:
# Dramas, International Movies, Romantic Movies                21
# Dramas, International Movies                                 15
# Horror Movies, International Movies                           9
# Comedies, Dramas, International Movies                        8
# Comedies, International Movies, Romantic Movies               4
# Children & Family Movies, Dramas, International Movies        3
# Dramas, Faith & Spirituality, International Movies            3
# Children & Family Movies, Dramas, Sports Movies               2
# Dramas, International Movies, Sports Movies                   2
# Comedies, International Movies                                2
# Action & Adventure, International Movies                      1
# Comedies, Horror Movies, International Movies                 1
# Dramas, International Movies, Music & Musicals                1
# Documentaries, Faith & Spirituality, International Movies     1
# Dramas, Independent Movies, International Movies              1
# Children & Family Movies                                      1
# Action & Adventure, Dramas, Faith & Spirituality              1
# Action & Adventure, Dramas, International Movies              1
# Name: listed_in, dtype: int64

# %%
plt.figure(figsize = (20, 8))
listed_in = listed_in_count["listed_in"].value_counts()[:15]
sns.barplot(x = listed_in, y = listed_in.index, palette = "Dark2")

plt.title('Movies Genre From Indonesia in Netflix',size=16)
plt.xlabel('NUMBER Of TITLES', size=14)
plt.ylabel('GENRE', size=14)
plt.xticks(rotation = 45)
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.25, p.get_height()+0.25), va = 'bottom', color = 'black')

# %% [markdown]
# There are 14 genres of Indonesian movies on Netflix, but the most dominant are international movies, dramas and romantic movies.

# %% [markdown]
# ## **6.WHO ARE THE MOVIE DIRECTORS & ACTORS FROM INDONESIA ?** <a name="6"></a>

# %% [markdown]
# ### *Movies Directors*

# %%
temp_df = df_indonesia[df_indonesia['type']=='Movie'] ##filter movie
temp_df['director'].value_counts()
# Out:
# Rocky Soraya                         5
# Angga Dwimas Sasongko                5
# Hanung Bramantyo                     5
# Riri Riza                            5
# Fajar Bustomi, Pidi Baiq             3
# Rano Karno                           3
# Andibachtiar Yusuf                   3
# Upi Avianto                          2
# Rako Prijanto                        2
# Raditya Dika                         2
# Rizal Mantovani                      2
# Nia Dinata                           2
# Ifa Isfansyah                        2
# Agasyah Karim, Khalid Kashogi        1
# Garin Nugroho                        1
# Lucky Kuswandi                       1
# Iman Brotoseno                       1
# Timo Tjahjanto, Kimo Stamboel        1
# Timo Tjahjanto                       1
# Rudy Soedjarwo                       1
# Hanung Bramantyo, Meisa Felaroze     1
# Kuntz Agus                           1
# Awi Suryadi                          1
# Sridhar Jetty                        1
# Gareth Evans                         1
# Sunil Soraya                         1
# Rocky Soraya, Anggy Umbara           1
# Hadrah Daeng Ratu                    1
# Guntur Soeharjanto                   1
# Archie Hekagery                      1
# Hanung Bramantyo, Pandu Adjisurya    1
# Mohammad Irfan Ramly                 1
# Fajar Bustomi                        1
# Rizki Balki                          1
# Monty Tiwa                           1
# Noviandra Santosa                    1
# Charles Gozali, Bagus Bramanti       1
# Jastis Arimba                        1
# Sabrina Rochelle Kalangie            1
# Edwin                                1
# Yandy Laurens                        1
# Naya Anindita                        1
# Lasja Fauzia Susatyo                 1
# Chandra Liow                         1
# Kenzo Maihara, Amandha Wyanto        1
# Ertanto Robby Soediskam              1
# Sammaria Sari Simanjuntak            1
# Chairun Nissa                        1
# Rudy Soedjarwo, Riri Riza            1
# Name: director, dtype: int64

# %%
temp_df = df_indonesia[df_indonesia['type']=='Movie']

plt.figure(figsize = (15, 8))
ax = sns.countplot(y="director", data=temp_df, palette = "colorblind",order=temp_df['director'].value_counts().index[0:10])
plt.title('Top 10 Movie Directors From Indonesia',size=16)
plt.xlabel('TITLES',size=12)
plt.ylabel('DIRECTORS', size=12)
plt.show()

# %% [markdown]
# ### *Actors*

# %%
cast_count = temp_df.copy()
cast_count = pd.concat([cast_count, temp_df["cast"].str.split(",", expand = True)], axis = 1)
cast_count
# Out:
#      show_id   type                                  title  \
# 452     s453  Movie                          A Perfect Fit
# 534     s535  Movie                    Si Doel the Movie 2
# 1090   s1091  Movie  Story of Kale: When Someone's in Love
# 1136   s1137  Movie                   Tersanjung the Movie
# 1221   s1222  Movie              Generasi 90an: Melankolia
# ...      ...    ...                                    ...
# 8317   s8318  Movie                          The Gathering
# 8374   s8375  Movie                      The Jungle School
# 8472   s8473  Movie                     The Rainbow Troops
# 8509   s8510  Movie           The Sinking Of Van Der Wijck
# 8725   s8726  Movie                   What's Up With Love?
#
#                                director  \
# 452                   Hadrah Daeng Ratu
# 534                          Rano Karno
# 1090              Angga Dwimas Sasongko
# 1136  Hanung Bramantyo, Pandu Adjisurya
# 1221               Mohammad Irfan Ramly
# ...                                 ...
# 8317                         Nia Dinata
# 8374                          Riri Riza
# 8472                          Riri Riza
# 8509                       Sunil Soraya
# 8725          Rudy Soedjarwo, Riri Riza
#
#                                                    cast    country  \
# 452   Nadya Arina, Refal Hady, Giorgino Abraham, Ang...  Indonesia
# 534   Maudy Koesnaedi, Rano Karno, Cornelia Agatha, ...  Indonesia
# 1090  Ardhito Pramono, Aurélie Moeremans, Arya Salok...  Indonesia
# 1136  Clara Bernadeth, Giorgino Abraham, Kevin Ardil...  Indonesia
# 1221  Ari Irham, Aghniny Haque, Taskya Namya, Marcel...  Indonesia
# ...                                                 ...        ...
# 8317  Cut Mini Theo, Tora Sudiro, Aida Nurmala, Sury...  Indonesia
# 8374  Prisia Nasution, Nyungsang Bungo, Rukman Rosad...  Indonesia
# 8472  Cut Mini Theo, Ikranagara, Lukman Sardi, Ario ...  Indonesia
# 8509  Herjunot Ali, Pevita Pearce, Reza Rahadian, Ra...  Indonesia
# 8725  Dian Sastrowardoyo, Nicholas Saputra, Ladya Ch...  Indonesia
#
#               date_added  release_year rating duration  ...                 8  \
# 452        July 15, 2021          2021  TV-PG  113 min  ...    Mathias Muchus
# 534         July 6, 2021          2019   TV-G   95 min  ...              None
# 1090       April 8, 2021          2020  TV-PG   78 min  ...              None
# 1136       April 1, 2021          2021  TV-14  114 min  ...   Sacha Stevenson
# 1221      March 11, 2021          2020  TV-14   94 min  ...              None
# ...                  ...           ...    ...      ...  ...               ...
# 8317    December 8, 2018          2003  TV-14  124 min  ...       Wilza Lubis
# 8374    October 30, 2018          2013  TV-PG   90 min  ...              None
# 8472    October 21, 2018          2008  TV-PG  119 min  ...              None
# 8509  September 28, 2018          2013  TV-14  163 min  ...              None
# 8725    December 8, 2018          2002      R  110 min  ...              None
#
#                   9             10                11             12  \
# 452      Ayu Laksmi   I Made Sidia   Dominique Sanda   Bryan Domani
# 534            None           None              None           None
# 1090           None           None              None           None
# 1136           None           None              None           None
# 1221           None           None              None           None
# ...             ...            ...               ...            ...
# 8317   Nico Siahaan           None              None           None
# 8374           None           None              None           None
# 8472           None           None              None           None
# 8509           None           None              None           None
# 8725           None           None              None           None
#
#                  13          14             15    16    17
# 452    Wafda Saifan   Yayu Unru   Dave Hendrik  None  None
# 534            None        None           None  None  None
# 1090           None        None           None  None  None
# 1136           None        None           None  None  None
# 1221           None        None           None  None  None
# ...             ...         ...            ...   ...   ...
# 8317           None        None           None  None  None
# 8374           None        None           None  None  None
# 8472           None        None           None  None  None
# 8509           None        None           None  None  None
# 8725           None        None           None  None  None
#
# [77 rows x 31 columns]

# %%
cast_count = cast_count.melt(id_vars = ["type", "title"], value_vars = range(10), value_name = "cast")
cast_count = cast_count[cast_count["cast"].notna()]
cast_count
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_131808\1243889351.py:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   cast_count = cast_count.melt(id_vars = ["type", "title"], value_vars = range(10), value_name = "cast")
#       type                                  title variable               cast
# 0    Movie                          A Perfect Fit        0        Nadya Arina
# 1    Movie                    Si Doel the Movie 2        0    Maudy Koesnaedi
# 2    Movie  Story of Kale: When Someone's in Love        0    Ardhito Pramono
# 3    Movie                   Tersanjung the Movie        0    Clara Bernadeth
# 4    Movie              Generasi 90an: Melankolia        0          Ari Irham
# ..     ...                                    ...      ...                ...
# 750  Movie          Cahaya Dari Timur Beta Maluku        9   Bebeto Leutually
# 753  Movie                Filosofi Kopi The Movie        9          Westny Dj
# 759  Movie                               Merantau        9        Ratna Galih
# 760  Movie                                 Single        9         Dede Yusuf
# 765  Movie                          The Gathering        9       Nico Siahaan
#
# [607 rows x 4 columns]

# %%
cast_count["cast"].nunique()
# Out:
# 443

# %%
plt.figure(figsize = (12, 8))
cast = cast_count["cast"].value_counts()[:10]
sns.barplot(x = cast, y = cast.index, palette = "gist_ncar")
plt.title('Top 10 Actor From Indonesia',size=16)
plt.xlabel('CASTING', size=14)
plt.ylabel('NAME', size=14)
plt.xticks(rotation = 45)
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.25, p.get_height()+0.25), va = 'bottom', color = 'black')

# %% [markdown]
# ## **7. CONCLUSION** <a name="7"></a>

# %% [markdown]
# ## *Reference*
